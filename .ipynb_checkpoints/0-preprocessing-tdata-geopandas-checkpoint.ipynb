# %%
from datetime import datetime
import pandas as pd
import geopandas as gpd

# %%
# Predefined variable for title and version
date = datetime.now()
# Enter
initials = "mw"
site = "samoa"

version = f"{initials}-{site}-{date.strftime('%d%m%Y')}"
print(version)
# Out:
# mw-samoa-27022026

# %%
# Read reference tdata with correct schema 
tdata = gpd.read_file(f"training-data/{version}.geojson")

# %%
tdata
# Out:
#       lulc_class  value_id                      geometry
# 0    Settlements         5  POINT (-171.80608 -13.82372)
# 1    Settlements         5   POINT (-171.8146 -13.82825)
# 2    Settlements         5  POINT (-171.81379 -13.82703)
# 3    Settlements         5   POINT (-171.8214 -13.82675)
# 4    Settlements         5   POINT (-171.80683 -13.8275)
# ..           ...       ...                           ...
# 393    Grassland         3  POINT (-172.10402 -13.84666)
# 394    Grassland         3  POINT (-172.10385 -13.84695)
# 395    Grassland         3  POINT (-172.10818 -13.84091)
# 396    Grassland         3   POINT (-172.10788 -13.8411)
# 397    Grassland         3   POINT (-172.1087 -13.84097)
#
# [398 rows x 3 columns]

# %%
tdata = gpd.read_file("training-data/mw-samoa-27022026.geojson")

# %%
print('list of', tdata['lulc_class'].nunique(),'unique classes')
print(tdata['lulc_class'].unique())
# Out:
# list of 6 unique classes
# ['Settlements' 'Forest' 'Cropland' 'Grassland' 'Wetlands' 'Land']

# %%
print(tdata['lulc_class'].value_counts())
print('total gps points',(len(tdata)))
# Out:
# lulc_class
# Settlements    92
# Land           79
# Forest         72
# Grassland      55
# Cropland       50
# Wetlands       50
# Name: count, dtype: int64
# total gps points 398

# %%
# tdata.loc[tdata['LULC_class'] == 'Shrubs', 'LULC_class'] = 'Grassland'

# tdata.loc[tdata['LULC_class'] == 'Shallow_ocean', 'LULC_class'] = 'Water'
# tdata.loc[tdata['LULC_class'] == 'Coral_reef', 'LULC_class'] = 'Water'
# tdata.loc[tdata['LULC_class'] == 'Seagrass', 'LULC_class'] = 'Water'
# tdata.loc[tdata['LULC_class'] == 'Deep_ocean', 'LULC_class'] = 'Water'
# tdata.loc[tdata['LULC_class'] == 'Surface_water', 'LULC_class'] = 'Water'

# %%
# tdata.loc[tdata['LULC_class'] == 'Grassland', 'LULC_class'] = 'Grazing_Cropland'
# tdata.loc[tdata['LULC_class'] == 'Cropland', 'LULC_class'] = 'Grazing_Cropland'

# %%
# Define two lists
old_categories = ['Forest', 'Cropland', 'Grassland', 'Wetlands', 'Settlements', 'Land']
new_groups = [1, 2, 3, 4, 5, 6]

# Create the mapping dictionary
category_mapping = dict(zip(old_categories, new_groups))

# Apply mapping
tdata['lulc_code'] = tdata['lulc_class'].map(category_mapping)

# %%
print(tdata['lulc_code'].value_counts())
print('total gps points',(len(tdata)))
# Out:
# lulc_code
# 5    92
# 6    79
# 1    72
# 3    55
# 2    50
# 4    50
# Name: count, dtype: int64
# total gps points 398

# %%
len(tdata)
# Out:
# 398

# %%
# 1) Show current cross-tab of class -> codes to inspect inconsistency
print("Cross-tab of LULC_class vs LULC_code (counts):")
ct = pd.crosstab(tdata['lulc_class'], tdata['lulc_code'])
display(ct)
# Out:
# Cross-tab of LULC_class vs LULC_code (counts):
# lulc_code     1   2   3   4   5   6
# lulc_class
# Cropland      0  50   0   0   0   0
# Forest       72   0   0   0   0   0
# Grassland     0   0  55   0   0   0
# Land          0   0   0   0   0  79
# Settlements   0   0   0   0  92   0
# Wetlands      0   0   0  50   0   0

# %%
tdata.explore(column='lulc_class')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1aa2757b43345b5dbb0f7b27ec3e413 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend lulc_class&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;lulc_class&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;Cropland&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#2ca02c&#x27;&gt;&lt;/span&gt;Forest&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9467bd&#x27;&gt;&lt;/span&gt;Grassland&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e377c2&#x27;&gt;&lt;/span&gt;Land&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#bcbd22&#x27;&gt;&lt;/span&gt;Settlements&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;Wetlands&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1aa2757b43345b5dbb0f7b27ec3e413&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1aa2757b43345b5dbb0f7b27ec3e413 = L.map(
#                 &quot;map_a1aa2757b43345b5dbb0f7b27ec3e413&quot;,
#                 {
#                     center: [-13.7458412883748, -172.1182380895078],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a1aa2757b43345b5dbb0f7b27ec3e413);
#
#
#
#
#
#             var tile_layer_661f0b9a4e0397bc78a649c7b03f1c04 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_661f0b9a4e0397bc78a649c7b03f1c04.addTo(map_a1aa2757b43345b5dbb0f7b27ec3e413);
#
#
#             map_a1aa2757b43345b5dbb0f7b27ec3e413.fitBounds(
#                 [[-14.04193606163444, -172.78990843767986], [-13.44974651511516, -171.44656774133574]],
#                 {}
#             );
#
#
#         function geo_json_54df7abba95eeacaf12e62b74f875fc4_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;1

# %%
# tdata = tdata.drop(columns=["fid"])
# tdata = tdata.drop(columns=["id"])
# tdata = tdata.drop(columns=["Descriptio"])
# tdata = tdata.drop(columns=["Long"])
# tdata = tdata.drop(columns=["Lat"])
# tdata

# %%
print(tdata['lulc_code'].value_counts())
print('total gps points',(len(tdata)))
# Out:
# lulc_code
# 5    92
# 6    79
# 1    72
# 3    55
# 2    50
# 4    50
# Name: count, dtype: int64
# total gps points 398

# %%
tdata.to_file("training-data/"f"{version}_postcard_4.geojson")
